# %%
# !pip install pymongo

# %%
pip install pymongo[srv]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://dbkate:19960908Lay@cluster0-diwns.mongodb.net/test?retryWrites=true&w=majority")

# %%
db = client.tweet

# %%
# to find users in California, USA
collection_users = db['users']

# %%
CAusers = collection_users.find({'location': 'California, USA'})  
CAusers

# %%
# %timeit collection_users.find({'location': 'California, USA'})
# Out:
# 4.68 µs ± 168 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
for CAusers in CAusers:  
    print(CAusers)
# Out:
# {'_id': ObjectId('5ea914721d3c07025123a2ea'), '': '2', 'id': '897886435818192896', 'id_str': '897886435818192896', 'name': 'Sally Bernal', 'screen_name': 'SallyBernal5', 'location': 'California, USA', 'url': '', 'description': 'Mother of three. Grandmother of one . Love is Love . Family is everything', 'translator_type': 'none', 'protected': 'False', 'verified': 'False', 'followers_count': '47', 'friends_count': '263', 'listed_count': '0', 'favourites_count': '18979', 'statuses_count': '4699', 'created_at': 'Wed Aug 16 18:23:03 +0000 2017', 'utc_offset': '', 'time_zone': '', 'geo_enabled': 'False', 'lang': '', 'contributors_enabled': 'False', 'is_translator': 'False', 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': 'False', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background
# ...

# %%
count = collection_users.find({'location': 'California, USA'}).count()
count
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 217

# %%
# remove the id:3039944423
result = collection_users.remove({'id':3039944423})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.

# %%
# find if the tweets contain the word 'Biden'
collection_tw = db['tweets']

# %%
fbiden = collection_tw.find({'tweet': {'$regex': '^[Biden]'}})
print(fbiden)

# %%
for i in fbiden:  
    print(i)
# Out:
# {'_id': ObjectId('5ea9153d1d3c0702512404d5'), '': '72', 'tweet': 'it really is all about peeling away ~just enough~ voters to repeat 2016. don’t fall for the far-right/left trolling. don’t fall for disinformation campaigns manufactured by the kremlin...again.'}
# {'_id': ObjectId('5ea9153d1d3c0702512404fd'), '': '112', 'tweet': 'i think it goes even beyond that...'}
# {'_id': ObjectId('5ea9153d1d3c0702512405e5'), '': '344', 'tweet': 'Blah...blah...blah 🙄'}
# {'_id': ObjectId('5ea9153d1d3c070251240663'), '': '470', 'tweet': 'Big shout out to @JulieButcher, who is doing a major service keeping us informed about Glendale City Hall!! Glendale council members appointed a new interim City Clerk today #MyGlendale'}
# {'_id': ObjectId('5ea9153d1d3c070251240813'), '': '902', 'tweet': 'BREITBART - NY Mag’s Olivia Nuzzi Asks Trump if He Deserves Re-election After She Compares Vietnam Death Count to #Coronavirus https://t.co/XnNiLuCFh8 https://t.co/vAcQr0FXm3'}
# ...

# %%
count = collection_tw.find({'tweet': {'$regex': '^[Biden]'}}).count()
count
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 82

# %%
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01-diwns.mongodb.net:27017', 'cluster0-shard-00-00-diwns.mongodb.net:27017', 'cluster0-shard-00-02-diwns.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='Cluster0-shard-0', ssl=True), 'tweet'), 'election.1')

# %%
# sort by followers_count
collection_ele = db['election']

# %%
result = collection_re.find().sort([("followers_count",-1)])

# %%
result = collection_ele.find({'text': {'$regex': '^[Trump]'}})
print(result)

# %%
for result in result:  
    print(result)
# Out:
# {'_id': ObjectId('5ea9062b1d3c0702512369b7'), '': '12', 'created_at': 'Tue Apr 28 03:56:00 +0000 2020', 'id': '1254982672650088450', 'id_str': '1254982672650088450', 'text': 'This is the BIGGEST ELECTION IN AMERICAN HISTORY, and the Democrats absolutely CANNOT fuck this thing up, 4/27/2020 https://t.co/9LhshkBRG0', 'source': '<a href="https://periscope.tv" rel="nofollow">Periscope</a>', 'truncated': 'False', 'in_reply_to_status_id': '', 'in_reply_to_status_id_str': '', 'in_reply_to_user_id': '', 'in_reply_to_user_id_str': '', 'in_reply_to_screen_name': '', 'user': "{'id': 481703659, 'id_str': '481703659', 'name': 'Stephen Ruderman', 'screen_name': 'SRUnfiltered', 'location': 'Berkeley, CA ↔️ Sacramento, CA', 'url': 'http://www.huffingtonpost.com/author/stephenruderman-732', 'description': 'Human #SFGiants and Baseball Encyclopedia, Baseball Announcer, Writer, Professional Guitarist and singer, and Unfiltered Progressive. #Bernie2020 #NotMeUs', 'translator_type': 'none', 'protected': 
# ...

# %%
count = collection_ele.find({'text': {'$regex': 'Trump.*'}}).count()
count
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 2602

# %%
# find the tweets contain the word 'Trump' and sort by favorite count
collection_re = db['retweet']

# %%
results = collection_re.find({'text':{'$regex': 'Trump.*'}}).sort('favorite_count', pymongo.DESCENDING)  
for result in results: 
    print(result)

# %%
collection_re.find({'text':{'$regex': 'Biden.*'}}).count()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 966

# %%
collection_re.find({'text':{'$regex': 'Trump.*'}}).count()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 1869

# %%
# count the time

# %%
results = collection_re.find({'text':{'$regex': 'Biden.*'}}).ort('favorite_count', pymongo.DESCENDING)
for result in results: 
    print(result)
# Out:
# {'_id': ObjectId('5eaddca28c662210bca94363'), '': '19', 'created_at': 'Mon Apr 27 17:00:15 +0000 2020', 'id': 1.2548176472978514e+18, 'id_str': 1.2548176472978514e+18, 'text': "@DavidAgStone @TeamPelosi @JoeBiden They will never let Sanders be the nominee. It's a duopoly. The election is sta… https://t.co/wVM8khJ3ih", 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': 'True', 'in_reply_to_status_id': '1.2547768393372058e+18', 'in_reply_to_status_id_str': '1254776839337205760', 'in_reply_to_user_id': '1.1936358790189998e+18', 'in_reply_to_user_id_str': '1193635879018999810', 'in_reply_to_screen_name': 'DavidAgStone', 'user': "{'id': 1120529957413801986, 'id_str': '1120529957413801986', 'name': 'RuththeTruth', 'screen_name': 'TruthRuththe', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 8, 'friends_count': 40, 'listed_count': 0, 'favourites_count': 20
# ...

# %%
results.count()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 966

# %%
t1 = time.time()
for result in results: 
    
    print(result) 
    
t2 = time.time()
t2-t1
# Out:
# {'_id': ObjectId('5eaddcb38c662210bca96b53'), '': '10243', 'created_at': 'Sat Apr 25 00:49:09 +0000 2020', 'id': 1.2538484895632835e+18, 'id_str': 1.2538484895632835e+18, 'text': 'It is my heartfelt goal to bring my 99 years of living into the voting booth on election day and vote Joe Biden (an… https://t.co/tZPk6GxU0a', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': 'True', 'in_reply_to_status_id': '', 'in_reply_to_status_id_str': '', 'in_reply_to_user_id': '', 'in_reply_to_user_id_str': '', 'in_reply_to_screen_name': '', 'user': "{'id': 637338906, 'id_str': '637338906', 'name': 'carl reiner', 'screen_name': 'carlreiner', 'location': 'Hollywood, CA', 'url': 'http://www.randomcontent.com', 'description': None, 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 352137, 'friends_count': 125, 'listed_count': 2045, 'favourites_count': 1385, 'statuses_count': 6377, 'created_at': 'Mon Jul 16 20:33:04 +0000 
# ...

# %%
results = collection_re.find({"favorite_count":{'$gt':2000}})
results

# %%
import time
from functools import lru_cache

# %%
@lru_cache(maxsize = 200)

def find():
    results = collection_re.find({'text':{'$regex': 'Biden.*'}}).sort('favorite_count', pymongo.DESCENDING)  
    return(result)
    

t1 = time.time()
print(find())

t2 = time.time()
t2-t1
# Out:
# {'_id': ObjectId('5eaddcb18c662210bca96a1f'), '': '9935', 'created_at': 'Tue Apr 28 05:40:37 +0000 2020', 'id': 1.2550090016260915e+18, 'id_str': 1.2550090016260915e+18, 'text': 'Jill Biden Talks ‘True Leadership‘ as Joe Biden Looks On in Bizarre Viral Video https://t.co/fWZy7KaSBt via @BreitbartNews', 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'truncated': 'False', 'in_reply_to_status_id': '', 'in_reply_to_status_id_str': '', 'in_reply_to_user_id': '', 'in_reply_to_user_id_str': '', 'in_reply_to_screen_name': '', 'user': '{\'id\': 21331501, \'id_str\': \'21331501\', \'name\': \'George...\', \'screen_name\': \'TexGEOas\', \'location\': \'The Free State of Texas\', \'url\': None, \'description\': \'The welfare of humanity \\nis always the alibi of tyrants"\\n                   -Camus\\n             \\nOn Twitter since 2009\\nShadow-banned / throttled since 2017\', \'translator_type\': \'none\', \'protected\': False, \'verified\': False, \'followers
# ...

# %%
find.cache_info()
# Out:
# CacheInfo(hits=0, misses=1, maxsize=200, currsize=1)

# %%
db.retweet.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)], 'ns': 'tweet.retweet'}}
